# %%
import requests
from bs4 import BeautifulSoup

# %%
r = requests.get("http://www.monsterindia.com/java-jobs-in-chennai.html/")
c = r.content

# %%
soup = BeautifulSoup(c, "html.parser")

# %%
beaut = BeautifulSoup.prettify(soup)

# %%
all = soup.find_all("div",{"type":"tuple"})

# %%
all
# Out:
# [<div class="jobwrap " id="22397171" type="tuple"><div class="row"><div class="col-sm-9"><div class="joblnk serachjoblnk"><div class="jtitle"><h2 class="seotitle"><a class="title_in" href="http://www.monsterindia.com/job-vacancy-tech-lead-core-java-wipro-limited-chennai-5-8-years-22397171.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;hlWords=core java,corejava,j2se,j2ee,java,jdk" target="_blank" title="Tech Lead Core Java"><span class="title_in" style="margin-right:2px;">Tech Lead  <span class="hightlighted_keyword">Core</span> <span class="hightlighted_keyword">Java</span></span></a></h2> </div><div class="jtxt"></div><div class="jtxt orange"><span>Wipro Limited</span></div> <div class="jtxt" title="Core Java"><span class="black">Keyskills: </span><span><span class="hightlighted_keyword">Core</span> <span class="hightlighted_keyword">Java</span></span></div><div class="jtxt jico ico1"><span>Chennai</span></div><div class="jtxt jico ico2"><span>5-8 years</span></div></div></div><div class="col-sm-3 clearfix"><div class="hidden-xs apply_spacer"></div><a class="btn pull-right apply" href="http://careers.wipro.com/share-search-for-jobs.aspx?jobcode=614442&amp;Subsource=MONSIND&amp;Source=WEB" rel="nofollow" role="button" target="_blank">Apply</a></div></div><div class="job_optmob visible-xs"><span></span><span class="cross"></span><span></span></div><div class="job_optwrap"><div class="job_optitem ico1 popover_this" data-container="body" data-content="&lt;div class='sc_ico share'&gt;&lt;a onclick=javascript:sharebutton('http://jobs.monsterindia.com/details/22397171.html?from=social_searchreslut');return false; href='javascript:void(0);' class='fb' rel='nofollow'&gt;&lt;/a&gt; &lt;a onclick=javascript:tweet_data('22397171');return false; href='javascript:void(0);' class='tw' rel='nofollow'&gt;&lt;/a&gt; &lt;a onclick=javascript:gplus('http://jobs.monsterindia.com/details/22397171.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;social_searchreslut');return false; href='javascript:void(0);' class='gp' rel='nofollow'&gt;&lt;/a&gt;&lt;a onclick=javascript:linkedIn('http://jobs.monsterindia.com/details/22397171.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;social_searchreslut');return false; href='javascript:void(0);' class='in' rel='nofollow'&gt;&lt;/a&gt;&lt;div class='fb_likewrap'&gt;&lt;iframe src='http://www.facebook.com/plugins/like.php?href=http://jobs.monsterindia.com/details/22397171.html?from=social_searchreslut&amp;width&amp;layout=button&amp;action=like&amp;show_faces=false&amp;share=false&amp;height=35' scrolling='no' frameborder='0' style='border:none; overflow:hidden; height:35px; width:60px;' allowTransparency='true'&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;" data-placement="top" data-toggle="popover" data-trigger="focus" tabindex="0">Share</div><div class="job_optitem ico7" itemprop="datePosted">Posted : 21st Jun 2018</div></div></div>,
#  <div class="jobwrap " id="22390854" type="tuple"><div class="row"><div class="col-sm-9"><div class="joblnk serachjoblnk"><div class="jtitle"><h2 class="seotitle"><a class="title_in" href="http://www.monsterindia.com/job-vacancy-developer-core-java-wipro-limited-chennai-3-5-years-22390854.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;hlWords=core java,corejava,j2se,j2ee,java,jdk" target="_blank" title="Developer Core Java"><span class="title_in" style="margin-right:2px;">Developer  <span class="hightlighted_keyword">Core</span> <span class="hightlighted_keyword">Java</span></span></a></h2> </div><div class="jtxt"></div><div class="jtxt orange"><span>Wipro Limited</span></div> <div class="jtxt" title="Core Java"><span class="black">Keyskills: </span><span><span class="hightlighted_keyword">Core</span> <span class="hightlighted_keyword">Java</span></span></div><div class="jtxt jico ico1"><span>Chennai</span></div><div class="jtxt jico ico2"><span>3-5 years</span></div></div></div><div class="col-sm-3 clearfix"><div class="hidden-xs apply_spacer"></div><a class="btn pull-right apply" href="http://careers.wipro.com/share-search-for-jobs.aspx?jobcode=604561&amp;Subsource=MONSIND&amp;Source=WEB" rel="nofollow" role="button" target="_blank">Apply</a></div></div><div class="job_optmob visible-xs"><span></span><span class="cross"></span><span></span></div><div class="job_optwrap"><div class="job_optitem ico1 popover_this" data-container="body" data-content="&lt;div class='sc_ico share'&gt;&lt;a onclick=javascript:sharebutton('http://jobs.monsterindia.com/details/22390854.html?from=social_searchreslut');return false; href='javascript:void(0);' class='fb' rel='nofollow'&gt;&lt;/a&gt; &lt;a onclick=javascript:tweet_data('22390854');return false; href='javascript:void(0);' class='tw' rel='nofollow'&gt;&lt;/a&gt; &lt;a onclick=javascript:gplus('http://jobs.monsterindia.com/details/22390854.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;social_searchreslut');return false; href='javascript:void(0);' class='gp' rel='nofollow'&gt;&lt;/a&gt;&lt;a onclick=javascript:linkedIn('http://jobs.monsterindia.com/details/22390854.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;social_searchreslut');return false; href='javascript:void(0);' class='in' rel='nofollow'&gt;&lt;/a&gt;&lt;div class='fb_likewrap'&gt;&lt;iframe src='http://www.facebook.com/plugins/like.php?href=http://jobs.monsterindia.com/details/22390854.html?from=social_searchreslut&amp;width&amp;layout=button&amp;action=like&amp;show_faces=false&amp;share=false&amp;height=35' scrolling='no' frameborder='0' style='border:none; overflow:hidden; height:35px; width:60px;' allowTransparency='true'&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;" data-placement="top" data-toggle="popover" data-trigger="focus" tabindex="0">Share</div><div class="job_optitem ico7" itemprop="datePosted">Posted : 19th Jun 2018</div></div></div>,
#  <div class="jobwrap " id="22390851" type="tuple"><div class="row"><div class="col-sm-9"><div class="joblnk serachjoblnk"><div class="jtitle"><h2 class="seotitle"><a class="title_in" href="http://www.monsterindia.com/job-vacancy-developer-core-java-wipro-limited-chennai-3-5-years-22390851.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;hlWords=core java,corejava,j2se,j2ee,java,jdk" target="_blank" title="Developer Core Java"><span class="title_in" style="margin-right:2px;">Developer  <span class="hightlighted_keyword">Core</span> <span class="hightlighted_keyword">Java</span></span></a></h2> </div><div class="jtxt"></div><div class="jtxt orange"><span>Wipro Limited</span></div> <div class="jtxt" title="Core Java"><span class="black">Keyskills: </span><span><span class="hightlighted_keyword">Core</span> <span class="hightlighted_keyword">Java</span></span></div><div class="jtxt jico ico1"><span>Chennai</span></div><div class="jtxt jico ico2"><span>3-5 years</span></div></div></div><div class="col-sm-3 clearfix"><div class="hidden-xs apply_spacer"></div><a class="btn pull-right apply" href="http://careers.wipro.com/share-search-for-jobs.aspx?jobcode=607571&amp;Subsource=MONSIND&amp;Source=WEB" rel="nofollow" role="button" target="_blank">Apply</a></div></div><div class="job_optmob visible-xs"><span></span><span class="cross"></span><span></span></div><div class="job_optwrap"><div class="job_optitem ico1 popover_this" data-container="body" data-content="&lt;div class='sc_ico share'&gt;&lt;a onclick=javascript:sharebutton('http://jobs.monsterindia.com/details/22390851.html?from=social_searchreslut');return false; href='javascript:void(0);' class='fb' rel='nofollow'&gt;&lt;/a&gt; &lt;a onclick=javascript:tweet_data('22390851');return false; href='javascript:void(0);' class='tw' rel='nofollow'&gt;&lt;/a&gt; &lt;a onclick=javascript:gplus('http://jobs.monsterindia.com/details/22390851.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;social_searchreslut');return false; href='javascript:void(0);' class='gp' rel='nofollow'&gt;&lt;/a&gt;&lt;a onclick=javascript:linkedIn('http://jobs.monsterindia.com/details/22390851.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;social_searchreslut');return false; href='javascript:void(0);' class='in' rel='nofollow'&gt;&lt;/a&gt;&lt;div class='fb_likewrap'&gt;&lt;iframe src='http://www.facebook.com/plugins/like.php?href=http://jobs.monsterindia.com/details/22390851.html?from=social_searchreslut&amp;width&amp;layout=button&amp;action=like&amp;show_faces=false&amp;share=false&amp;height=35' scrolling='no' frameborder='0' style='border:none; overflow:hidden; height:35px; width:60px;' allowTransparency='true'&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;" data-placement="top" data-toggle="popover" data-trigger="focus" tabindex="0">Share</div><div class="job_optitem ico7" itemprop="datePosted">Posted : 19th Jun 2018</div></div></div>,
#  <div class="jobwrap " id="22389371" type="tuple"><div class="row"><div class="col-sm-9"><div class="joblnk serachjoblnk"><div class="jtitle"><h2 class="seotitle"><a class="title_in" href="http://www.monsterindia.com/job-vacancy-developer-core-java-wipro-limited-chennai-3-5-years-22389371.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;hlWords=core java,corejava,j2se,j2ee,java,jdk" target="_blank" title="Developer Core Java"><span class="title_in" style="margin-right:2px;">Developer  <span class="hightlighted_keyword">Core</span> <span class="hightlighted_keyword">Java</span></span></a></h2> </div><div class="jtxt"></div><div class="jtxt orange"><span>Wipro Limited</span></div> <div class="jtxt" title="Core Java"><span class="black">Keyskills: </span><span><span class="hightlighted_keyword">Core</span> <span class="hightlighted_keyword">Java</span></span></div><div class="jtxt jico ico1"><span>Chennai</span></div><div class="jtxt jico ico2"><span>3-5 years</span></div></div></div><div class="col-sm-3 clearfix"><div class="hidden-xs apply_spacer"></div><a class="btn pull-right apply" href="http://careers.wipro.com/share-search-for-jobs.aspx?jobcode=601065&amp;Subsource=MONSIND&amp;Source=WEB" rel="nofollow" role="button" target="_blank">Apply</a></div></div><div class="job_optmob visible-xs"><span></span><span class="cross"></span><span></span></div><div class="job_optwrap"><div class="job_optitem ico1 popover_this" data-container="body" data-content="&lt;div class='sc_ico share'&gt;&lt;a onclick=javascript:sharebutton('http://jobs.monsterindia.com/details/22389371.html?from=social_searchreslut');return false; href='javascript:void(0);' class='fb' rel='nofollow'&gt;&lt;/a&gt; &lt;a onclick=javascript:tweet_data('22389371');return false; href='javascript:void(0);' class='tw' rel='nofollow'&gt;&lt;/a&gt; &lt;a onclick=javascript:gplus('http://jobs.monsterindia.com/details/22389371.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;social_searchreslut');return false; href='javascript:void(0);' class='gp' rel='nofollow'&gt;&lt;/a&gt;&lt;a onclick=javascript:linkedIn('http://jobs.monsterindia.com/details/22389371.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;social_searchreslut');return false; href='javascript:void(0);' class='in' rel='nofollow'&gt;&lt;/a&gt;&lt;div class='fb_likewrap'&gt;&lt;iframe src='http://www.facebook.com/plugins/like.php?href=http://jobs.monsterindia.com/details/22389371.html?from=social_searchreslut&amp;width&amp;layout=button&amp;action=like&amp;show_faces=false&amp;share=false&amp;height=35' scrolling='no' frameborder='0' style='border:none; overflow:hidden; height:35px; width:60px;' allowTransparency='true'&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;" data-placement="top" data-toggle="popover" data-trigger="focus" tabindex="0">Share</div><div class="job_optitem ico7" itemprop="datePosted">Posted : 19th Jun 2018</div></div></div>,
#  <div class="jobwrap " id="22041717" type="tuple"><div class="row"><div class="col-sm-9"><div class="joblnk serachjoblnk"><div class="jtitle"><h2 class="seotitle"><a class="title_in" href="http://www.monsterindia.com/job-vacancy-developer-core-java-wipro-limited-chennai-3-5-years-22041717.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;hlWords=core java,corejava,j2se,j2ee,java,jdk" target="_blank" title="Developer Core Java"><span class="title_in" style="margin-right:2px;">Developer  <span class="hightlighted_keyword">Core</span> <span class="hightlighted_keyword">Java</span></span></a></h2> </div><div class="jtxt"></div><div class="jtxt orange"><span>Wipro Limited</span></div> <div class="jtxt" title="Core Java"><span class="black">Keyskills: </span><span><span class="hightlighted_keyword">Core</span> <span class="hightlighted_keyword">Java</span></span></div><div class="jtxt jico ico1"><span>Chennai</span></div><div class="jtxt jico ico2"><span>3-5 years</span></div></div></div><div class="col-sm-3 clearfix"><div class="hidden-xs apply_spacer"></div><a class="btn pull-right apply" href="http://careers.wipro.com/share-search-for-jobs.aspx?jobcode=556395&amp;Subsource=MONSIND&amp;Source=WEB" rel="nofollow" role="button" target="_blank">Apply</a></div></div><div class="job_optmob visible-xs"><span></span><span class="cross"></span><span></span></div><div class="job_optwrap"><div class="job_optitem ico1 popover_this" data-container="body" data-content="&lt;div class='sc_ico share'&gt;&lt;a onclick=javascript:sharebutton('http://jobs.monsterindia.com/details/22041717.html?from=social_searchreslut');return false; href='javascript:void(0);' class='fb' rel='nofollow'&gt;&lt;/a&gt; &lt;a onclick=javascript:tweet_data('22041717');return false; href='javascript:void(0);' class='tw' rel='nofollow'&gt;&lt;/a&gt; &lt;a onclick=javascript:gplus('http://jobs.monsterindia.com/details/22041717.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;social_searchreslut');return false; href='javascript:void(0);' class='gp' rel='nofollow'&gt;&lt;/a&gt;&lt;a onclick=javascript:linkedIn('http://jobs.monsterindia.com/details/22041717.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;social_searchreslut');return false; href='javascript:void(0);' class='in' rel='nofollow'&gt;&lt;/a&gt;&lt;div class='fb_likewrap'&gt;&lt;iframe src='http://www.facebook.com/plugins/like.php?href=http://jobs.monsterindia.com/details/22041717.html?from=social_searchreslut&amp;width&amp;layout=button&amp;action=like&amp;show_faces=false&amp;share=false&amp;height=35' scrolling='no' frameborder='0' style='border:none; overflow:hidden; height:35px; width:60px;' allowTransparency='true'&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;" data-placement="top" data-toggle="popover" data-trigger="focus" tabindex="0">Share</div><div class="job_optitem ico7" itemprop="datePosted">Posted : 19th Jun 2018</div></div></div>,
#  <div class="jobwrap " id="21321928" type="tuple"><div class="row"><div class="col-sm-9"><div class="joblnk serachjoblnk"><div class="jtitle"><h2 class="seotitle"><a class="title_in" href="http://www.monsterindia.com/job-vacancy-developer-core-java-wipro-limited-chennai-3-5-years-21321928.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;hlWords=core java,corejava,j2se,j2ee,java,jdk" target="_blank" title="Developer Core Java"><span class="title_in" style="margin-right:2px;">Developer  <span class="hightlighted_keyword">Core</span> <span class="hightlighted_keyword">Java</span></span></a></h2> </div><div class="jtxt"></div><div class="jtxt orange"><span>Wipro Limited</span></div> <div class="jtxt" title="Core Java"><span class="black">Keyskills: </span><span><span class="hightlighted_keyword">Core</span> <span class="hightlighted_keyword">Java</span></span></div><div class="jtxt jico ico1"><span>Chennai</span></div><div class="jtxt jico ico2"><span>3-5 years</span></div></div></div><div class="col-sm-3 clearfix"><div class="hidden-xs apply_spacer"></div><a class="btn pull-right apply" href="http://careers.wipro.com/share-search-for-jobs.aspx?jobcode=541668&amp;Subsource=MONSIND&amp;Source=WEB" rel="nofollow" role="button" target="_blank">Apply</a></div></div><div class="job_optmob visible-xs"><span></span><span class="cross"></span><span></span></div><div class="job_optwrap"><div class="job_optitem ico1 popover_this" data-container="body" data-content="&lt;div class='sc_ico share'&gt;&lt;a onclick=javascript:sharebutton('http://jobs.monsterindia.com/details/21321928.html?from=social_searchreslut');return false; href='javascript:void(0);' class='fb' rel='nofollow'&gt;&lt;/a&gt; &lt;a onclick=javascript:tweet_data('21321928');return false; href='javascript:void(0);' class='tw' rel='nofollow'&gt;&lt;/a&gt; &lt;a onclick=javascript:gplus('http://jobs.monsterindia.com/details/21321928.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;social_searchreslut');return false; href='javascript:void(0);' class='gp' rel='nofollow'&gt;&lt;/a&gt;&lt;a onclick=javascript:linkedIn('http://jobs.monsterindia.com/details/21321928.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;social_searchreslut');return false; href='javascript:void(0);' class='in' rel='nofollow'&gt;&lt;/a&gt;&lt;div class='fb_likewrap'&gt;&lt;iframe src='http://www.facebook.com/plugins/like.php?href=http://jobs.monsterindia.com/details/21321928.html?from=social_searchreslut&amp;width&amp;layout=button&amp;action=like&amp;show_faces=false&amp;share=false&amp;height=35' scrolling='no' frameborder='0' style='border:none; overflow:hidden; height:35px; width:60px;' allowTransparency='true'&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;" data-placement="top" data-toggle="popover" data-trigger="focus" tabindex="0">Share</div><div class="job_optitem ico7" itemprop="datePosted">Posted : 19th Jun 2018</div></div></div>,
#  <div class="jobwrap " id="22357838" type="tuple"><div class="row"><div class="col-sm-9"><div class="joblnk serachjoblnk"><div class="jtitle"><h2 class="seotitle"><a class="title_in" href="http://www.monsterindia.com/job-vacancy-core-java-advanced-java-j2ee-developer-openings-in-chennai-vertical-management-consultancy-chennai-3-6-years-22357838.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;hlWords=core java,corejava,j2se,j2ee,java,jdk" target="_blank" title="Core Java / Advanced JAVA / J2EE Developer openings in Chennai..."><span class="title_in" style="margin-right:2px;"><span class="hightlighted_keyword">Core</span> <span class="hightlighted_keyword">Java</span> / Advanced  <span class="hightlighted_keyword">JAVA</span> /  <span class="hightlighted_keyword">J2EE</span> Developer openings in Chennai</span></a></h2> </div><div class="jtxt"></div><div class="jtxt orange"><span>Vertical Management Consultancy</span></div> <div class="jtxt" title="Java, J2EE, Core JAVA, Advanced Java, Spring, Hibernate, JDBC, Servelets"><span class="black">Keyskills: </span><span><span class="hightlighted_keyword">Java</span>,   <span class="hightlighted_keyword">J2EE</span>,   <span class="hightlighted_keyword">Core</span> <span class="hightlighted_keyword">JAVA</span>...,  Advanced  <span class="hightlighted_keyword">Java</span>,  Spring,  Hibernate</span></div><div class="jtxt"><span class="black">Summary: </span><span>We are looking for a Java developer with hands-on experience in developing web based applications and web services. Develops and implements software programming applications and components. </span></div><div class="jtxt jico ico1"><span>Chennai</span></div><div class="jtxt jico ico2"><span>3-6 years</span></div></div></div><div class="col-sm-3 clearfix"><div class="hidden-xs apply_spacer"></div><a class="btn pull-right apply" href="http://my.monsterindia.com/application_confirmation.html?action=apply&amp;job=22357838&amp;from=search_result&amp;title=Core Java / Advanced JAVA / J2EE Developer openings in Chennai...&amp;int_spl=TechInternal_gulf_sr_apply_single" rel="nofollow" role="button" target="_blank">Apply</a></div></div><div class="job_optmob visible-xs"><span></span><span class="cross"></span><span></span></div><div class="job_optwrap"><div class="job_optitem ico1 popover_this" data-container="body" data-content="&lt;div class='sc_ico share'&gt;&lt;a onclick=javascript:sharebutton('http://jobs.monsterindia.com/details/22357838.html?from=social_searchreslut');return false; href='javascript:void(0);' class='fb' rel='nofollow'&gt;&lt;/a&gt; &lt;a onclick=javascript:tweet_data('22357838');return false; href='javascript:void(0);' class='tw' rel='nofollow'&gt;&lt;/a&gt; &lt;a onclick=javascript:gplus('http://jobs.monsterindia.com/details/22357838.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;social_searchreslut');return false; href='javascript:void(0);' class='gp' rel='nofollow'&gt;&lt;/a&gt;&lt;a onclick=javascript:linkedIn('http://jobs.monsterindia.com/details/22357838.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;social_searchreslut');return false; href='javascript:void(0);' class='in' rel='nofollow'&gt;&lt;/a&gt;&lt;div class='fb_likewrap'&gt;&lt;iframe src='http://www.facebook.com/plugins/like.php?href=http://jobs.monsterindia.com/details/22357838.html?from=social_searchreslut&amp;width&amp;layout=button&amp;action=like&amp;show_faces=false&amp;share=false&amp;height=35' scrolling='no' frameborder='0' style='border:none; overflow:hidden; height:35px; width:60px;' allowTransparency='true'&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;" data-placement="top" data-toggle="popover" data-trigger="focus" tabindex="0">Share</div><div class="job_op ...
#  <div class="jobwrap " id="22395500" type="tuple"><div class="row"><div class="col-sm-9"><div class="joblnk serachjoblnk"><div class="jtitle"><h2 class="seotitle"><a class="title_in" href="http://www.monsterindia.com/job-vacancy-java-developer-asp-net-walk-in-interview-chennai-visakhapatnam-0-5-years-22395500.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;hlWords=core java,corejava,j2se,j2ee,java,jdk" target="_blank" title="Java Developer &amp; Asp.net walk in Interview"><span class="title_in" style="margin-right:2px;"><span class="hightlighted_keyword">Java</span> Developer &amp; Asp.Net walk in Interview</span></a></h2> </div><div class="jtxt"></div><div class="jtxt orange"><span>Confidential</span></div> <div class="jtxt" title="core java,Java Developer,Java,JSP,Hibernate,J2EE"><span class="black">Keyskills: </span><span><span class="hightlighted_keyword">core</span> <span class="hightlighted_keyword">java</span>,  <span class="hightlighted_keyword">Java</span> Developer,  <span class="hightlighted_keyword">Java</span>..., JSP, Hibernate,  <span class="hightlighted_keyword">J2EE</span></span></div><div class="jtxt"><span class="black">Summary: </span><span>1.Strong in CORE JAVA , J2EE,
#                    2. Strong in Spring
#                    3. Strong in JDBC, Hibernate
#                    ASP.NET with .NET Framework 4.0, 3.5.
#                    ASP.NE..</span></div><div class="jtxt jico ico1"><span>Chennai, Visakhapatnam</span></div><div class="jtxt jico ico2"><span>0-5 years</span></div></div></div><div class="col-sm-3 clearfix"><div class="hidden-xs apply_spacer"></div><a class="btn pull-right apply" href="http://my.monsterindia.com/application_confirmation.html?action=apply&amp;job=22395500&amp;from=search_result&amp;title=Java Developer &amp; Asp.net walk in Interview&amp;int_spl=TechInternal_gulf_sr_apply_single" rel="nofollow" role="button" target="_blank">Apply</a></div></div><div class="job_optmob visible-xs"><span></span><span class="cross"></span><span></span></div><div class="job_optwrap"><div class="job_optitem ico1 popover_this" data-container="body" data-content="&lt;div class='sc_ico share'&gt;&lt;a onclick=javascript:sharebutton('http://jobs.monsterindia.com/details/22395500.html?from=social_searchreslut');return false; href='javascript:void(0);' class='fb' rel='nofollow'&gt;&lt;/a&gt; &lt;a onclick=javascript:tweet_data('22395500');return false; href='javascript:void(0);' class='tw' rel='nofollow'&gt;&lt;/a&gt; &lt;a onclick=javascript:gplus('http://jobs.monsterindia.com/details/22395500.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;social_searchreslut');return false; href='javascript:void(0);' class='gp' rel='nofollow'&gt;&lt;/a&gt;&lt;a onclick=javascript:linkedIn('http://jobs.monsterindia.com/details/22395500.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;social_searchreslut');return false; href='javascript:void(0);' class='in' rel='nofollow'&gt;&lt;/a&gt;&lt;div class='fb_likewrap'&gt;&lt;iframe src='http://www.facebook.com/plugins/like.php?href=http://jobs.monsterindia.com/details/22395500.html?from=social_searchreslut&amp;width&amp;layout=button&amp;action=like&amp;show_faces=false&amp;share=false&amp;height=35' scrolling='no' frameborder='0' style='border:none; overflow:hidden; height:35px; width:60px;' allowTransparency='true'&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;" data-placement="top" data-toggle="popover" data-trigger="focus" tabindex="0">Share</div><div class="job_optitem ico7" itemprop="datePosted">Posted : 20th Jun 2018</div></div></div>,
#  <div class="jobwrap " id="22390790" type="tuple"><div class="row"><div class="col-sm-9"><div class="joblnk serachjoblnk"><div class="jtitle"><h2 class="seotitle"><a class="title_in" href="http://www.monsterindia.com/job-vacancy-java-developer-roljobs-technology-services-private-limited-chennai-3-5-years-22390790.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;hlWords=core java,corejava,j2se,j2ee,java,jdk" target="_blank" title="Java Developer"><span class="title_in" style="margin-right:2px;"><span class="hightlighted_keyword">Java</span> Developer</span></a></h2> </div><div class="jtxt"></div><div class="jtxt orange"><span>Roljobs Technology Services Private Limited</span></div> <div class="jtxt" title="Java,Core JAVA Scripts,J2EE,Core JAVA,JAVA Developer,Spring,Spring Framework,Spring Batch,Spring Boot,Spring Core"><span class="black">Keyskills: </span><span><span class="hightlighted_keyword">Java</span>,  <span class="hightlighted_keyword">Core</span> <span class="hightlighted_keyword">JAVA</span> Scripts,  <span class="hightlighted_keyword">J2EE</span>...,  <span class="hightlighted_keyword">Core</span> <span class="hightlighted_keyword">JAVA</span>,  <span class="hightlighted_keyword">JAVA</span> Developer, Spring</span></div><div class="jtxt"><span class="black">Summary: </span><span>Java
#   Spring</span></div><div class="jtxt jico ico1"><span>Chennai</span></div><div class="jtxt jico ico2"><span>3-5 years</span></div></div></div><div class="col-sm-3 clearfix"><div class="hidden-xs apply_spacer"></div><a class="btn pull-right apply" href="http://my.monsterindia.com/application_confirmation.html?action=apply&amp;job=22390790&amp;from=search_result&amp;title=Java Developer&amp;int_spl=TechInternal_gulf_sr_apply_single" rel="nofollow" role="button" target="_blank">Apply</a></div></div><div class="job_optmob visible-xs"><span></span><span class="cross"></span><span></span></div><div class="job_optwrap"><div class="job_optitem ico1 popover_this" data-container="body" data-content="&lt;div class='sc_ico share'&gt;&lt;a onclick=javascript:sharebutton('http://jobs.monsterindia.com/details/22390790.html?from=social_searchreslut');return false; href='javascript:void(0);' class='fb' rel='nofollow'&gt;&lt;/a&gt; &lt;a onclick=javascript:tweet_data('22390790');return false; href='javascript:void(0);' class='tw' rel='nofollow'&gt;&lt;/a&gt; &lt;a onclick=javascript:gplus('http://jobs.monsterindia.com/details/22390790.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;social_searchreslut');return false; href='javascript:void(0);' class='gp' rel='nofollow'&gt;&lt;/a&gt;&lt;a onclick=javascript:linkedIn('http://jobs.monsterindia.com/details/22390790.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;social_searchreslut');return false; href='javascript:void(0);' class='in' rel='nofollow'&gt;&lt;/a&gt;&lt;div class='fb_likewrap'&gt;&lt;iframe src='http://www.facebook.com/plugins/like.php?href=http://jobs.monsterindia.com/details/22390790.html?from=social_searchreslut&amp;width&amp;layout=button&amp;action=like&amp;show_faces=false&amp;share=false&amp;height=35' scrolling='no' frameborder='0' style='border:none; overflow:hidden; height:35px; width:60px;' allowTransparency='true'&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;" data-placement="top" data-toggle="popover" data-trigger="focus" tabindex="0">Share</div><div class="job_optitem ico7" itemprop="datePosted">Posted : 19th Jun 2018</div></div></div>,
#  <div class="jobwrap " id="22389524" type="tuple"><div class="row"><div class="col-sm-9"><div class="joblnk serachjoblnk"><div class="jtitle"><h2 class="seotitle"><a class="title_in" href="http://www.monsterindia.com/job-vacancy-java-professioanls-data-software-research-company-private-limited-chennai-4-7-years-22389524.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;hlWords=core java,corejava,j2se,j2ee,java,jdk" target="_blank" title="Java Professioanls!!!!"><span class="title_in" style="margin-right:2px;"><span class="hightlighted_keyword">Java</span> Professioanls!!!!</span></a></h2> <em class="jobtype" title="Walk-in Jobs">Walk-in Jobs</em> </div><div class="jtxt"></div><div class="jtxt orange"><span>Data Software Research Company Private Limited</span></div> <div class="jtxt" title="Java,Spring,Hibernate,J2EE,Core Java,Java Developer,Java Programmer"><span class="black">Keyskills: </span><span><span class="hightlighted_keyword">Java</span>, Spring, Hibernate,  <span class="hightlighted_keyword">J2EE</span>...,  <span class="hightlighted_keyword">Core</span> <span class="hightlighted_keyword">Java</span>,  <span class="hightlighted_keyword">Java</span> Developer,  <span class="hightlighted_keyword">Java</span></span></div><div class="jtxt"><span class="black">Summary: </span><span>Greetings from DSRC Private Limited!!!!
#
#
#  Employment Type : Permanent
#  Notice Period : 30 Days
#
#
#  Skills:
#
#  Essential Skills: Java, Spring, Hibernate, Javascript, Angular JS, JQuery, SQL Server, RE..</span></div><div class="jtxt jico ico1"><span>Chennai</span></div><div class="jtxt jico ico2"><span>4-7 years</span></div></div></div><div class="col-sm-3 clearfix"><div class="hidden-xs apply_spacer"></div><a class="btn pull-right apply" href="http://my.monsterindia.com/application_confirmation.html?action=apply&amp;job=22389524&amp;from=search_result&amp;title=Java Professioanls!!!!&amp;int_spl=TechInternal_gulf_sr_apply_single" rel="nofollow" role="button" target="_blank">Apply</a></div></div><div class="job_optmob visible-xs"><span></span><span class="cross"></span><span></span></div><div class="job_optwrap"><div class="job_optitem ico1 popover_this" data-container="body" data-content="&lt;div class='sc_ico share'&gt;&lt;a onclick=javascript:sharebutton('http://jobs.monsterindia.com/details/22389524.html?from=social_searchreslut');return false; href='javascript:void(0);' class='fb' rel='nofollow'&gt;&lt;/a&gt; &lt;a onclick=javascript:tweet_data('22389524');return false; href='javascript:void(0);' class='tw' rel='nofollow'&gt;&lt;/a&gt; &lt;a onclick=javascript:gplus('http://jobs.monsterindia.com/details/22389524.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;social_searchreslut');return false; href='javascript:void(0);' class='gp' rel='nofollow'&gt;&lt;/a&gt;&lt;a onclick=javascript:linkedIn('http://jobs.monsterindia.com/details/22389524.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;social_searchreslut');return false; href='javascript:void(0);' class='in' rel='nofollow'&gt;&lt;/a&gt;&lt;div class='fb_likewrap'&gt;&lt;iframe src='http://www.facebook.com/plugins/like.php?href=http://jobs.monsterindia.com/details/22389524.html?from=social_searchreslut&amp;width&amp;layout=button&amp;action=like&amp;show_faces=false&amp;share=false&amp;height=35' scrolling='no' frameborder='0' style='border:none; overflow:hidden; height:35px; width:60px;' allowTransparency='true'&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;" data-placement="top" data-toggle="popover" data-trigger="focus" tabindex="0">Share</div><div class="job_optitem ico7" itemprop="datePosted">Posted : 19th Jun 2018</div></div></div>,
#  <div class="jobwrap " id="22387988" type="tuple"><div class="row"><div class="col-sm-9"><div class="joblnk serachjoblnk"><div class="jtitle"><h2 class="seotitle"><a class="title_in" href="http://www.monsterindia.com/job-vacancy-java-developer-infosys-bpm-limited-chennai-2-4-years-22387988.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;hlWords=core java,corejava,j2se,j2ee,java,jdk" target="_blank" title="Java Developer "><span class="title_in" style="margin-right:2px;"><span class="hightlighted_keyword">Java</span> Developer</span></a></h2> <em class="jobtype" title="Walk-in Jobs">Walk-in Jobs</em> </div><div class="jtxt"></div><div class="jtxt orange"><span>Infosys BPM Limited</span></div> <div class="jtxt" title="Java,webserviceJ2EE Scripts,Core JAVA Scripts,CSS.,JAVA J2EE,Servlets,Struts,JAVA Developer,Hibernate,Hibernate,Shell Scripting,J2EE,Core Java Developer"><span class="black">Keyskills: </span><span><span class="hightlighted_keyword">Core</span> <span class="hightlighted_keyword">JAVA</span> Scripts, CSS.,  <span class="hightlighted_keyword">JAVA</span> <span class="hightlighted_keyword">J2EE</span>...,  <span class="hightlighted_keyword">J2EE</span>,  <span class="hightlighted_keyword">Core</span> <span class="hightlighted_keyword">Java</span> Developer... <span class="hightlighted_keyword">Java</span>, webserviceJ2EE Script</span></div><div class="jtxt"><span class="black">Summary: </span><span>Infosys BPM Ltd is hiring for “Java Developer” for  Chennai on  22nd June 2018
#
#  Reference DS-Shalini
#
#  Interview details
#  Time:9:30-10:30 am
#  Date:22nd Jun18
#
#  Venue:
#  Infosys BPM
#  4th Floor , South Win..</span></div><div class="jtxt jico ico1"><span>Chennai</span></div><div class="jtxt jico ico2"><span>2-4 years</span></div></div></div><div class="col-sm-3 clearfix"><div class="hidden-xs apply_spacer"></div><a class="btn pull-right apply" href="http://my.monsterindia.com/application_confirmation.html?action=apply&amp;job=22387988&amp;from=search_result&amp;title=Java Developer &amp;int_spl=TechInternal_gulf_sr_apply_single" rel="nofollow" role="button" target="_blank">Apply</a></div></div><div class="job_optmob visible-xs"><span></span><span class="cross"></span><span></span></div><div class="job_optwrap"><div class="job_optitem ico1 popover_this" data-container="body" data-content="&lt;div class='sc_ico share'&gt;&lt;a onclick=javascript:sharebutton('http://jobs.monsterindia.com/details/22387988.html?from=social_searchreslut');return false; href='javascript:void(0);' class='fb' rel='nofollow'&gt;&lt;/a&gt; &lt;a onclick=javascript:tweet_data('22387988');return false; href='javascript:void(0);' class='tw' rel='nofollow'&gt;&lt;/a&gt; &lt;a onclick=javascript:gplus('http://jobs.monsterindia.com/details/22387988.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;social_searchreslut');return false; href='javascript:void(0);' class='gp' rel='nofollow'&gt;&lt;/a&gt;&lt;a onclick=javascript:linkedIn('http://jobs.monsterindia.com/details/22387988.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;social_searchreslut');return false; href='javascript:void(0);' class='in' rel='nofollow'&gt;&lt;/a&gt;&lt;div class='fb_likewrap'&gt;&lt;iframe src='http://www.facebook.com/plugins/like.php?href=http://jobs.monsterindia.com/details/22387988.html?from=social_searchreslut&amp;width&amp;layout=button&amp;action=like&amp;show_faces=false&amp;share=false&amp;height=35' scrolling='no' frameborder='0' style='border:none; overflow:hidden; height:35px; width:60px;' allowTransparency='true'&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;" data-placement="top" data-toggle="popover" data-trigger="focus" tabindex="0">Share</div><div class="job_optitem ico7" itemprop="datePosted">Posted : 19th Jun 2018</div></div></div>,
#  <div class="jobwrap " id="22361313" type="tuple"><div class="row"><div class="col-sm-9"><div class="joblnk serachjoblnk"><div class="jtitle"><h2 class="seotitle"><a class="title_in" href="http://www.monsterindia.com/job-vacancy-core-java-developer-with-multithreading-collections-oops-for-chennai-2coms-consulting-private-limited-chennai-3-8-years-22361313.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;hlWords=core java,corejava,j2se,j2ee,java,jdk" target="_blank" title="Core Java Developer with Multithreading, collections, OOPS for Chennai..."><span class="title_in" style="margin-right:2px;"><span class="hightlighted_keyword">Core</span> <span class="hightlighted_keyword">Java</span> Developer with Multithreading, collections, OOPS for Chennai</span></a></h2> </div><div class="jtxt"></div><div class="jtxt orange"><span>2COMS Consulting Private Limited</span></div> <div class="jtxt" title=" Multithreading, Core Java, OOPS, Collections, Java Developer, Object Oriented Programming, OOP, object oriented"><span class="black">Keyskills: </span><span>Multithreading,   <span class="hightlighted_keyword">Core</span> <span class="hightlighted_keyword">Java</span>...,  OOPS,  Collections,   <span class="hightlighted_keyword">Java</span> Developer</span></div><div class="jtxt"><span class="black">Summary: </span><span>Greetings From 2Coms Looking for Core Java developer Skill: Core Java Developer with Multithreading, collections, OOPS concepts Exp: 3+ yrs to 9 Years Location: Chennai (DLF) Notice Period: Immedi..</span></div><div class="jtxt jico ico1"><span>Chennai</span></div><div class="jtxt jico ico2"><span>3-8 years</span></div></div></div><div class="col-sm-3 clearfix"><div class="hidden-xs apply_spacer"></div><a class="btn pull-right apply" href="http://my.monsterindia.com/application_confirmation.html?action=apply&amp;job=22361313&amp;from=search_result&amp;title=Core Java Developer with Multithreading, collections, OOPS for Chennai...&amp;int_spl=TechInternal_gulf_sr_apply_single" rel="nofollow" role="button" target="_blank">Apply</a></div></div><div class="job_optmob visible-xs"><span></span><span class="cross"></span><span></span></div><div class="job_optwrap"><div class="job_optitem ico1 popover_this" data-container="body" data-content="&lt;div class='sc_ico share'&gt;&lt;a onclick=javascript:sharebutton('http://jobs.monsterindia.com/details/22361313.html?from=social_searchreslut');return false; href='javascript:void(0);' class='fb' rel='nofollow'&gt;&lt;/a&gt; &lt;a onclick=javascript:tweet_data('22361313');return false; href='javascript:void(0);' class='tw' rel='nofollow'&gt;&lt;/a&gt; &lt;a onclick=javascript:gplus('http://jobs.monsterindia.com/details/22361313.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;social_searchreslut');return false; href='javascript:void(0);' class='gp' rel='nofollow'&gt;&lt;/a&gt;&lt;a onclick=javascript:linkedIn('http://jobs.monsterindia.com/details/22361313.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;social_searchreslut');return false; href='javascript:void(0);' class='in' rel='nofollow'&gt;&lt;/a&gt;&lt;div class='fb_likewrap'&gt;&lt;iframe src='http://www.facebook.com/plugins/like.php?href=http://jobs.monsterindia.com/details/22361313.html?from=social_searchreslut&amp;width&amp;layout=button&amp;action=like&amp;show_faces=false&amp;share=false&amp;height=35' scrolling='no' frameborder='0' style='border:none; overflow:hidden; height:35px; width:60px;' allowTransparency='true'&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;" data-placement="top" data-toggle="popover" data-trigger="focus" tabindex="0">Share</div><div class="job_optitem ico7" itemprop="datePosted">Posted : 12th Jun 2018</div></div></div>,
#  <div class="jobwrap " id="21938097" type="tuple"><div class="row"><div class="col-sm-9"><div class="joblnk serachjoblnk"><div class="jtitle"><h2 class="seotitle"><a class="title_in" href="http://www.monsterindia.com/job-vacancy-tech-lead-core-java-wipro-limited-chennai-5-8-years-21938097.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;hlWords=core java,corejava,j2se,j2ee,java,jdk" target="_blank" title="Tech Lead Core Java"><span class="title_in" style="margin-right:2px;">Tech Lead  <span class="hightlighted_keyword">Core</span> <span class="hightlighted_keyword">Java</span></span></a></h2> </div><div class="jtxt"></div><div class="jtxt orange"><span>Wipro Limited</span></div> <div class="jtxt" title="Core Java"><span class="black">Keyskills: </span><span><span class="hightlighted_keyword">Core</span> <span class="hightlighted_keyword">Java</span></span></div><div class="jtxt jico ico1"><span>Chennai</span></div><div class="jtxt jico ico2"><span>5-8 years</span></div></div></div><div class="col-sm-3 clearfix"><div class="hidden-xs apply_spacer"></div><a class="btn pull-right apply" href="http://careers.wipro.com/share-search-for-jobs.aspx?jobcode=564494&amp;Subsource=MONSIND&amp;Source=WEB" rel="nofollow" role="button" target="_blank">Apply</a></div></div><div class="job_optmob visible-xs"><span></span><span class="cross"></span><span></span></div><div class="job_optwrap"><div class="job_optitem ico1 popover_this" data-container="body" data-content="&lt;div class='sc_ico share'&gt;&lt;a onclick=javascript:sharebutton('http://jobs.monsterindia.com/details/21938097.html?from=social_searchreslut');return false; href='javascript:void(0);' class='fb' rel='nofollow'&gt;&lt;/a&gt; &lt;a onclick=javascript:tweet_data('21938097');return false; href='javascript:void(0);' class='tw' rel='nofollow'&gt;&lt;/a&gt; &lt;a onclick=javascript:gplus('http://jobs.monsterindia.com/details/21938097.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;social_searchreslut');return false; href='javascript:void(0);' class='gp' rel='nofollow'&gt;&lt;/a&gt;&lt;a onclick=javascript:linkedIn('http://jobs.monsterindia.com/details/21938097.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;social_searchreslut');return false; href='javascript:void(0);' class='in' rel='nofollow'&gt;&lt;/a&gt;&lt;div class='fb_likewrap'&gt;&lt;iframe src='http://www.facebook.com/plugins/like.php?href=http://jobs.monsterindia.com/details/21938097.html?from=social_searchreslut&amp;width&amp;layout=button&amp;action=like&amp;show_faces=false&amp;share=false&amp;height=35' scrolling='no' frameborder='0' style='border:none; overflow:hidden; height:35px; width:60px;' allowTransparency='true'&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;" data-placement="top" data-toggle="popover" data-trigger="focus" tabindex="0">Share</div><div class="job_optitem ico7" itemprop="datePosted">Posted : 21st Jun 2018</div></div></div>,
# ...
#  <div class="jobwrap " id="22349308" type="tuple"><div class="row"><div class="col-sm-9"><div class="joblnk serachjoblnk"><div class="jtitle"><h2 class="seotitle"><a class="title_in" href="http://www.monsterindia.com/job-vacancy-java-developer-front-end-development-software-data-india-limited-chennai-4-8-years-22349308.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;hlWords=core java,corejava,j2se,j2ee,java,jdk" target="_blank" title="Java Developer (front end Development)"><span class="title_in" style="margin-right:2px;"><span class="hightlighted_keyword">Java</span> Developer (front end Development)</span></a></h2> </div><div class="jtxt"></div><div class="jtxt orange"><span>Software Data India Limited</span></div> <div class="jtxt" title="jsp, servlets, core java, JDBC, Fullstack developer, Full stack development, J2ee, Java"><span class="black">Keyskills: </span><span>jsp,  servlets,   <span class="hightlighted_keyword">core</span> <span class="hightlighted_keyword">java</span>... stack development,   <span class="hightlighted_keyword">J2ee</span>,   <span class="hightlighted_keyword">Java</span></span></div><div class="jtxt"><span class="black">Summary: </span><span>Our client is ond ore top renowned IT MNC and scouting for talented resources in Chennai offering work opportunity based at B'lore and Delhi/NCR work location.</span></div><div class="jtxt jico ico1"><span>Chennai</span></div><div class="jtxt jico ico2"><span>4-8 years</span></div></div></div><div class="col-sm-3 clearfix"><div class="hidden-xs apply_spacer"></div><a class="btn pull-right apply" href="http://my.monsterindia.com/application_confirmation.html?action=apply&amp;job=22349308&amp;from=search_result&amp;title=Java Developer (front end Development)&amp;int_spl=TechInternal_gulf_sr_apply_single" rel="nofollow" role="button" target="_blank">Apply</a></div></div><div class="job_optmob visible-xs"><span></span><span class="cross"></span><span></span></div><div class="job_optwrap"><div class="job_optitem ico1 popover_this" data-container="body" data-content="&lt;div class='sc_ico share'&gt;&lt;a onclick=javascript:sharebutton('http://jobs.monsterindia.com/details/22349308.html?from=social_searchreslut');return false; href='javascript:void(0);' class='fb' rel='nofollow'&gt;&lt;/a&gt; &lt;a onclick=javascript:tweet_data('22349308');return false; href='javascript:void(0);' class='tw' rel='nofollow'&gt;&lt;/a&gt; &lt;a onclick=javascript:gplus('http://jobs.monsterindia.com/details/22349308.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;social_searchreslut');return false; href='javascript:void(0);' class='gp' rel='nofollow'&gt;&lt;/a&gt;&lt;a onclick=javascript:linkedIn('http://jobs.monsterindia.com/details/22349308.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;social_searchreslut');return false; href='javascript:void(0);' class='in' rel='nofollow'&gt;&lt;/a&gt;&lt;div class='fb_likewrap'&gt;&lt;iframe src='http://www.facebook.com/plugins/like.php?href=http://jobs.monsterindia.com/details/22349308.html?from=social_searchreslut&amp;width&amp;layout=button&amp;action=like&amp;show_faces=false&amp;share=false&amp;height=35' scrolling='no' frameborder='0' style='border:none; overflow:hidden; height:35px; width:60px;' allowTransparency='true'&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;" data-placement="top" data-toggle="popover" data-trigger="focus" tabindex="0">Share</div><div class="job_optitem ico7" itemprop="datePosted">Posted : 8th Jun 2018</div></div></div>,
#  <div class="jobwrap " id="22346943" type="tuple"><div class="row"><div class="col-sm-9"><div class="joblnk serachjoblnk"><div class="jtitle"><h2 class="seotitle"><a class="title_in" href="http://www.monsterindia.com/job-vacancy-excillent-opportunity-for-java-developer-c2h-position-f2f-on-9th-crown-solutions-india-private-limited-chennai-3-8-years-22346943.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;hlWords=core java,corejava,j2se,j2ee,java,jdk" target="_blank" title="Excillent Opportunity for Java Developer C2H Position F2F on 9th..."><span class="title_in" style="margin-right:2px;">Excillent Opportunity for  <span class="hightlighted_keyword">Java</span> Developer C2H Position F2F on 9th</span></a></h2> </div><div class="jtxt"></div><div class="jtxt orange"><span>Crown Solutions India Private Limited</span></div> <div class="jtxt" title=" Java, j2ee, core java"><span class="black">Keyskills: </span><span><span class="hightlighted_keyword">Java</span>,   <span class="hightlighted_keyword">j2ee</span>,   <span class="hightlighted_keyword">core</span> <span class="hightlighted_keyword">java</span></span></div><div class="jtxt"><span class="black">Summary: </span><span>We have immediate job opportunity for Java developer for Chennai Location. Associates with office notice period more than 30days need not apply. Exp-3+ Interested for F2F ON 9.06.2018 Work Locatio..</span></div><div class="jtxt jico ico1"><span>Chennai</span></div><div class="jtxt jico ico2"><span>3-8 years</span></div></div></div><div class="col-sm-3 clearfix"><div class="hidden-xs apply_spacer"></div><a class="btn pull-right apply" href="http://my.monsterindia.com/application_confirmation.html?action=apply&amp;job=22346943&amp;from=search_result&amp;title=Excillent Opportunity for Java Developer C2H Position F2F on 9th...&amp;int_spl=TechInternal_gulf_sr_apply_single" rel="nofollow" role="button" target="_blank">Apply</a></div></div><div class="job_optmob visible-xs"><span></span><span class="cross"></span><span></span></div><div class="job_optwrap"><div class="job_optitem ico1 popover_this" data-container="body" data-content="&lt;div class='sc_ico share'&gt;&lt;a onclick=javascript:sharebutton('http://jobs.monsterindia.com/details/22346943.html?from=social_searchreslut');return false; href='javascript:void(0);' class='fb' rel='nofollow'&gt;&lt;/a&gt; &lt;a onclick=javascript:tweet_data('22346943');return false; href='javascript:void(0);' class='tw' rel='nofollow'&gt;&lt;/a&gt; &lt;a onclick=javascript:gplus('http://jobs.monsterindia.com/details/22346943.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;social_searchreslut');return false; href='javascript:void(0);' class='gp' rel='nofollow'&gt;&lt;/a&gt;&lt;a onclick=javascript:linkedIn('http://jobs.monsterindia.com/details/22346943.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;social_searchreslut');return false; href='javascript:void(0);' class='in' rel='nofollow'&gt;&lt;/a&gt;&lt;div class='fb_likewrap'&gt;&lt;iframe src='http://www.facebook.com/plugins/like.php?href=http://jobs.monsterindia.com/details/22346943.html?from=social_searchreslut&amp;width&amp;layout=button&amp;action=like&amp;show_faces=false&amp;share=false&amp;height=35' scrolling='no' frameborder='0' style='border:none; overflow:hidden; height:35px; width:60px;' allowTransparency='true'&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;" data-placement="top" data-toggle="popover" data-trigger="focus" tabindex="0">Share</div><div class="job_optitem ico7" itemprop="datePosted">Posted : 8th Jun 2018</div></div></div>,
#  <div class="jobwrap " id="22296987" type="tuple"><div class="row"><div class="col-sm-9"><div class="joblnk serachjoblnk"><div class="jtitle"><h2 class="seotitle"><a class="title_in" href="http://www.monsterindia.com/job-vacancy-x22-core-java-developer-x22-iqura-technologies-private-limited-chennai-3-9-years-22296987.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;hlWords=core java,corejava,j2se,j2ee,java,jdk" target="_blank" title='"Core Java Developer"'><span class="title_in" style="margin-right:2px;">" <span class="hightlighted_keyword">Core</span> <span class="hightlighted_keyword">Java</span> Developer"</span></a></h2> </div><div class="jtxt"></div><div class="jtxt orange"><span>IQura Technologies Private Limited</span></div> <div class="jtxt" title="Core Java, Spring MVC ,Spring Boot ,Spring Batch ,Spring JDBC, Rest API ,HTML/CSS , Angular Js/Node JS/React JS"><span class="black">Keyskills: </span><span><span class="hightlighted_keyword">Core</span> <span class="hightlighted_keyword">Java</span>,  Spring MVC , Spring</span></div><div class="jtxt"><span class="black">Summary: </span><span>"We are looking for Core Java Developer"</span></div><div class="jtxt jico ico1"><span>Chennai</span></div><div class="jtxt jico ico2"><span>3-9 years</span></div></div></div><div class="col-sm-3 clearfix"><div class="hidden-xs apply_spacer"></div><a class="btn pull-right apply" href='http://my.monsterindia.com/application_confirmation.html?action=apply&amp;job=22296987&amp;from=search_result&amp;title="Core Java Developer"&amp;int_spl=TechInternal_gulf_sr_apply_single' rel="nofollow" role="button" target="_blank">Apply</a></div></div><div class="job_optmob visible-xs"><span></span><span class="cross"></span><span></span></div><div class="job_optwrap"><div class="job_optitem ico1 popover_this" data-container="body" data-content="&lt;div class='sc_ico share'&gt;&lt;a onclick=javascript:sharebutton('http://jobs.monsterindia.com/details/22296987.html?from=social_searchreslut');return false; href='javascript:void(0);' class='fb' rel='nofollow'&gt;&lt;/a&gt; &lt;a onclick=javascript:tweet_data('22296987');return false; href='javascript:void(0);' class='tw' rel='nofollow'&gt;&lt;/a&gt; &lt;a onclick=javascript:gplus('http://jobs.monsterindia.com/details/22296987.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;social_searchreslut');return false; href='javascript:void(0);' class='gp' rel='nofollow'&gt;&lt;/a&gt;&lt;a onclick=javascript:linkedIn('http://jobs.monsterindia.com/details/22296987.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;social_searchreslut');return false; href='javascript:void(0);' class='in' rel='nofollow'&gt;&lt;/a&gt;&lt;div class='fb_likewrap'&gt;&lt;iframe src='http://www.facebook.com/plugins/like.php?href=http://jobs.monsterindia.com/details/22296987.html?from=social_searchreslut&amp;width&amp;layout=button&amp;action=like&amp;show_faces=false&amp;share=false&amp;height=35' scrolling='no' frameborder='0' style='border:none; overflow:hidden; height:35px; width:60px;' allowTransparency='true'&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;" data-placement="top" data-toggle="popover" data-trigger="focus" tabindex="0">Share</div><div class="job_optitem ico7" itemprop="datePosted">Posted : 30th May 2018</div></div></div>,
#  <div class="jobwrap " id="22358565" type="tuple"><div class="row"><div class="col-sm-9"><div class="joblnk serachjoblnk"><div class="jtitle"><h2 class="seotitle"><a class="title_in" href="http://www.monsterindia.com/job-vacancy-java-developer-savvyan-technologies-private-limited-chennai-5-7-years-22358565.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;hlWords=core java,corejava,j2se,j2ee,java,jdk" target="_blank" title="Java Developer "><span class="title_in" style="margin-right:2px;"><span class="hightlighted_keyword">Java</span> Developer</span></a></h2> </div><div class="jtxt"></div><div class="jtxt orange"><span>Savvyan Technologies Private Limited</span></div> <div class="jtxt" title="Core Java, Java Script, AJAX, Hibernate, Spring,SQL/MYSQL/Oracle"><span class="black">Keyskills: </span><span><span class="hightlighted_keyword">Core</span> <span class="hightlighted_keyword">Java</span>,  javascript,  AJAX</span></div><div class="jtxt"><span class="black">Summary: </span><span>Java Developer
#   Location :Chennai
#   Exp 5-7 years
#   </span></div><div class="jtxt jico ico1"><span>Chennai</span></div><div class="jtxt jico ico2"><span>5-7 years</span></div></div></div><div class="col-sm-3 clearfix"><div class="hidden-xs apply_spacer"></div><a class="btn pull-right apply" href="http://my.monsterindia.com/application_confirmation.html?action=apply&amp;job=22358565&amp;from=search_result&amp;title=Java Developer &amp;int_spl=TechInternal_gulf_sr_apply_single" rel="nofollow" role="button" target="_blank">Apply</a></div></div><div class="job_optmob visible-xs"><span></span><span class="cross"></span><span></span></div><div class="job_optwrap"><div class="job_optitem ico1 popover_this" data-container="body" data-content="&lt;div class='sc_ico share'&gt;&lt;a onclick=javascript:sharebutton('http://jobs.monsterindia.com/details/22358565.html?from=social_searchreslut');return false; href='javascript:void(0);' class='fb' rel='nofollow'&gt;&lt;/a&gt; &lt;a onclick=javascript:tweet_data('22358565');return false; href='javascript:void(0);' class='tw' rel='nofollow'&gt;&lt;/a&gt; &lt;a onclick=javascript:gplus('http://jobs.monsterindia.com/details/22358565.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;social_searchreslut');return false; href='javascript:void(0);' class='gp' rel='nofollow'&gt;&lt;/a&gt;&lt;a onclick=javascript:linkedIn('http://jobs.monsterindia.com/details/22358565.html?sig=js-1--1&amp;from=&amp;rfr=refine;fts=java;loc=3;day=365;ref=http:%2F%2Fjobsearch%2Emonsterindia%2Ecom%2Fsearch%2Ehtml;res_cnt=4%30&amp;social_searchreslut');return false; href='javascript:void(0);' class='in' rel='nofollow'&gt;&lt;/a&gt;&lt;div class='fb_likewrap'&gt;&lt;iframe src='http://www.facebook.com/plugins/like.php?href=http://jobs.monsterindia.com/details/22358565.html?from=social_searchreslut&amp;width&amp;layout=button&amp;action=like&amp;show_faces=false&amp;share=false&amp;height=35' scrolling='no' frameborder='0' style='border:none; overflow:hidden; height:35px; width:60px;' allowTransparency='true'&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;" data-placement="top" data-toggle="popover" data-trigger="focus" tabindex="0">Share</div><div class="job_optitem ico7" itemprop="datePosted">Posted : 12th Jun 2018</div></div></div>]

# %%
for item in all:
    print(item.find_all("div",{"class":"jtxt orange"})[0].text)
    print(item.find_all("h2",{"class":"seotitle"})[0].text)
    try:
        print(item.find_all("div",{"class":"jtxt jico ico1"})[0].text)
    except:
        print(None)
    try:
        print(item.find_all("div",{"class":"jtxt jico ico2"})[0].text)
    except:
        print(None)
    print("")
# Out:
# Wipro Limited
# Tech Lead  Core Java
# Chennai
# 5-8 years
#
# Wipro Limited
# Developer  Core Java
# Chennai
# 3-5 years
#
# Wipro Limited
# Developer  Core Java
# Chennai
# 3-5 years
#
# Wipro Limited
# Developer  Core Java
# Chennai
# 3-5 years
#
# Wipro Limited
# Developer  Core Java
# Chennai
# 3-5 years
#
# Wipro Limited
# Developer  Core Java
# Chennai
# 3-5 years
#
# Vertical Management Consultancy
# Core Java / Advanced  JAVA /  J2EE Developer openings in Chennai
# Chennai
# 3-6 years
#
# Confidential
# Java Developer & Asp.Net walk in Interview
# Chennai, Visakhapatnam
# 0-5 years
#
# Roljobs Technology Services Private Limited
# Java Developer
# Chennai
# 3-5 years
#
# Data Software Research Company Private Limited
# Java Professioanls!!!!
# Chennai
# 4-7 years
#
# Infosys BPM Limited
# Java Developer
# Chennai
# 2-4 years
#
# 2COMS Consulting Private Limited
# Core Java Developer with Multithreading, collections, OOPS for Chennai
# Chennai
# 3-8 years
#
# Wipro Limited
# Tech Lead  Core Java
# Chennai
# 5-8 years
#
# HR Addons
# Java Developer
# Chennai
# 4-7 years
#
# Cloud Axis Technologies
# Java Developer
# Chennai
# 0-0 years
#
# SP Staffing Services Private Limited
# We are having an opening for  Java Developer and DotNet Developer in MNC company.
# Chennai
# 3-6 years
#
# Perficient India
# Senior  Java Developer
# Chennai
# 4-12 years
#
# People Prime Worldwide Private Limited
# Immediate Opening at BA Continuum
# Mumbai, Chennai
# 5-10 years
#
# Comfyi Solution
# Core Java Developer
# Chennai
# 0-1 years
#
# Wilmer Software Solutions Private Limited
# Java /  J2ee with 5+ years of experience at Chennai location Notice period: 10-15 days
# Chennai, Pune
# 5-10 years
#
# Capgemini Technology Services India Limited
# Walk-in Interview -  Java Developer - Capgemini Chennai on 16th June 2018
# Chennai
# 4-10 years
#
# Infiniminds Private Limited
# J2Ee Developer
# None
# None
#
# Datamatics Global Services Limited
# Excellent opportunity with Datamatics for Senior  Java Developer position
# Chennai, Mumbai
# 5-8 years
#
# True Tech Solutions
# Core Java Developer :: Guindy location
# Chennai
# 3-7 years
#
# Vertical Management Consultancy
# JAVA /  J2EE /  Core JAVA / Advanced  JAVA Production and Application Support
# Chennai
# 2-6 years
#
# Stg Infotech India LLP
# Openings with STG For  Java with Spring Professionals
# Chennai
# 4-9 years
#
# Infiniminds Private Limited
# J2Ee Developer
# None
# None
#
# Crown Solutions India Private Limited
# Java Developer
# Chennai
# 3-4 years
#
# Larsen & Toubro Infotech  Ltd.
# Opening for  Java developer@Chennai
# Chennai
# 3-7 years
#
# savan Sudesh Babu (Proprietor Of Job Store Consulting)
# SENIOR  JAVA DEVELOPER
# None
# None
#
# Anlage Infotech India Private Limited
# Senior  Java Developer
# Chennai, Mumbai
# 5-8 years
#
# Infiniminds Private Limited
# J2EE Lead
# None
# None
#
# VGB IT Solutions
# Java /  J2ee- Developers / team lead / Architect
# Chennai, Mumbai
# 0-8 years
#
# 2COMS Consulting Private Limited
# Java Development Professionals
# Chennai
# 3-8 years
#
# Software Data India Limited
# Java Developer (front end Development)
# Chennai
# 4-8 years
#
# Crown Solutions India Private Limited
# Excillent Opportunity for  Java Developer C2H Position F2F on 9th
# Chennai
# 3-8 years
#
# IQura Technologies Private Limited
# " Core Java Developer"
# Chennai
# 3-9 years
#
# Savvyan Technologies Private Limited
# Java Developer
# Chennai
# 5-7 years

# %%
type(all)
# Out:
# bs4.element.ResultSet

# %%
len(all)
# Out:
# 38

# %%
comp = soup.find_all("div",{"class":"jtxt orange"})

# %%
for item in comp:
    print(item.text)
# Out:
# Wipro Limited
# Wipro Limited
# Wipro Limited
# Wipro Limited
# Wipro Limited
# Wipro Limited
# Vertical Management Consultancy
# Confidential
# Roljobs Technology Services Private Limited
# Data Software Research Company Private Limited
# Infosys BPM Limited
# 2COMS Consulting Private Limited
# Wipro Limited
# HR Addons
# Cloud Axis Technologies
# SP Staffing Services Private Limited
# Perficient India
# People Prime Worldwide Private Limited
# Comfyi Solution
# Wilmer Software Solutions Private Limited
# Capgemini Technology Services India Limited
# Infiniminds Private Limited
# Datamatics Global Services Limited
# True Tech Solutions
# Vertical Management Consultancy
# Stg Infotech India LLP
# Infiniminds Private Limited
# Crown Solutions India Private Limited
# Larsen & Toubro Infotech  Ltd.
# savan Sudesh Babu (Proprietor Of Job Store Consulting)
# Anlage Infotech India Private Limited
# Infiniminds Private Limited
# VGB IT Solutions
# 2COMS Consulting Private Limited
# Software Data India Limited
# Crown Solutions India Private Limited
# IQura Technologies Private Limited
# Savvyan Technologies Private Limited

# %%
title = soup.find_all("h2",{"class":"seotitle"})

# %%
for item in title:
    print(item.text)
# Out:
# Tech Lead  Core Java
# Developer  Core Java
# Developer  Core Java
# Developer  Core Java
# Developer  Core Java
# Developer  Core Java
# Core Java / Advanced  JAVA /  J2EE Developer openings in Chennai
# Java Developer & Asp.Net walk in Interview
# Java Developer
# Java Professioanls!!!!
# Java Developer
# Core Java Developer with Multithreading, collections, OOPS for Chennai
# Tech Lead  Core Java
# Java Developer
# Java Developer
# We are having an opening for  Java Developer and DotNet Developer in MNC company.
# Senior  Java Developer
# Immediate Opening at BA Continuum
# Core Java Developer
# Java /  J2ee with 5+ years of experience at Chennai location Notice period: 10-15 days
# Walk-in Interview -  Java Developer - Capgemini Chennai on 16th June 2018
# J2Ee Developer
# Excellent opportunity with Datamatics for Senior  Java Developer position
# Core Java Developer :: Guindy location
# JAVA /  J2EE /  Core JAVA / Advanced  JAVA Production and Application Support
# Openings with STG For  Java with Spring Professionals
# J2Ee Developer
# Java Developer
# Opening for  Java developer@Chennai
# SENIOR  JAVA DEVELOPER
# Senior  Java Developer
# J2EE Lead
# Java /  J2ee- Developers / team lead / Architect
# Java Development Professionals
# Java Developer (front end Development)
# Excillent Opportunity for  Java Developer C2H Position F2F on 9th
# " Core Java Developer"
# Java Developer

# %% [markdown]
# ----

# %%
location = soup.find_all("div",{"class":"jtxt jico ico1"})

# %%
for item in location:
    print(item.text)
# Out:
# Chennai
# Chennai
# Chennai
# Chennai
# Chennai
# Chennai
# Chennai
# Chennai, Visakhapatnam
# Chennai
# Chennai
# Chennai
# Chennai
# Chennai
# Chennai
# Chennai
# Chennai
# Chennai
# Mumbai, Chennai
# Chennai
# Chennai, Pune
# Chennai
# Chennai
# Chennai, Mumbai
# Chennai
# Chennai
# Chennai
# Chennai
# Chennai
# Chennai
# Chennai
# Chennai, Mumbai
# Chennai
# Chennai, Mumbai
# Chennai
# Chennai
# Chennai
# Chennai
# Chennai

# %%
yrs_of_exp = soup.find_all("div",{"class":"jtxt jico ico2"})

# %%
for item in yrs_of_exp:
    print(item.text)
# Out:
# 5-8 years
# 3-5 years
# 3-5 years
# 3-5 years
# 3-5 years
# 3-5 years
# 3-6 years
# 0-5 years
# 3-5 years
# 4-7 years
# 2-4 years
# 3-8 years
# 5-8 years
# 4-7 years
# 0-0 years
# 3-6 years
# 4-12 years
# 5-10 years
# 0-1 years
# 5-10 years
# 4-10 years
# 6-10 years
# 5-8 years
# 3-7 years
# 2-6 years
# 4-9 years
# 6-10 years
# 3-4 years
# 3-7 years
# 5-7 years
# 5-8 years
# 6-10 years
# 0-8 years
# 3-8 years
# 4-8 years
# 3-8 years
# 3-9 years
# 5-7 years

# %%
key_skills = soup.find_all("div",{"class":"jtxt"})

# %%
for item in key_skills:
    print(item.text)
# Out:
# Wipro Limited
# Keyskills: Core Java
# Chennai
# 5-8 years
#
# Wipro Limited
# Keyskills: Core Java
# Chennai
# 3-5 years
#
# Wipro Limited
# Keyskills: Core Java
# Chennai
# 3-5 years
#
# Wipro Limited
# Keyskills: Core Java
# Chennai
# 3-5 years
#
# Wipro Limited
# Keyskills: Core Java
# Chennai
# 3-5 years
#
# Wipro Limited
# Keyskills: Core Java
# Chennai
# 3-5 years
#
# Vertical Management Consultancy
# Keyskills: Java,   J2EE,   Core JAVA...,  Advanced  Java,  Spring,  Hibernate
# Summary: We are looking for a Java developer with hands-on experience in developing web based applications and web services. Develops and implements software programming applications and components.
# Chennai
# 3-6 years
#
# Confidential
# Keyskills: core java,  Java Developer,  Java..., JSP, Hibernate,  J2EE
#                   ASP.NE..
# Chennai, Visakhapatnam
# 0-5 years
#
# Roljobs Technology Services Private Limited
# Keyskills: Java,  Core JAVA Scripts,  J2EE...,  Core JAVA,  JAVA Developer, Spring
#  Spring
# Chennai
# 3-5 years
#
# Data Software Research Company Private Limited
# Keyskills: Java, Spring, Hibernate,  J2EE...,  Core Java,  Java Developer,  Java
# Essential Skills: Java, Spring, Hibernate, Javascript, Angular JS, JQuery, SQL Server, RE..
# Chennai
# 4-7 years
#
# Infosys BPM Limited
# Keyskills: Core JAVA Scripts, CSS.,  JAVA J2EE...,  J2EE,  Core Java Developer... Java, webserviceJ2EE Script
# 4th Floor , South Win..
# Chennai
# 2-4 years
#
# 2COMS Consulting Private Limited
# Keyskills: Multithreading,   Core Java...,  OOPS,  Collections,   Java Developer
# Summary: Greetings From 2Coms Looking for Core Java developer Skill: Core Java Developer with Multithreading, collections, OOPS concepts Exp: 3+ yrs to 9 Years Location: Chennai (DLF) Notice Period: Immedi..
# Chennai
# 3-8 years
#
# Wipro Limited
# Keyskills: Core Java
# Chennai
# 5-8 years
#
# HR Addons
# Keyskills: core java,  spring, springboot
# Summary: Urgently looking for java developer
# Chennai
# 4-7 years
#
# Cloud Axis Technologies
# Keyskills: Java Developer,  Core java,  Java..., Struts, JSP, Hibernate,  j2ee
# Summary: We are looking for a Java Developer in building high-performing, scalable, enterprise-grade applications.You will be part of a talented software team that works on mission-critical applications.
# Chennai
# 0-0 years
#
# SP Staffing Services Private Limited
# Keyskills: Developer,   Core Java... Java Developer, .Net
#  Notice ..
# Chennai
# 3-6 years
#
# Perficient India
# Keyskills: Java,  Core JAVA, spring
#  Notice/Availability - Max 30 days
# Chennai
# 4-12 years
#
# People Prime Worldwide Private Limited
# Keyskills: core java,  multithreading... risk,  agile,   j2ee,  python
# Summary: Designation: Analyst I Apps Prog. / Sr. Analyst Apps Prog. / Lead Analyst Experience: 5 Years to 12 Years. Date : - 23rd June 2018, Saturday Location: Mumbai / Hyderabad / Chennai. Note: We will o..
# Mumbai, Chennai
# 5-10 years
#
# Comfyi Solution
# Keyskills: " core java", oops,  freshers ... JAVA , "software fresher",
# Summary: software engineers to code in java platform in the real time environment. Walk in for a technical discussion directly to the below venue with two hard copy of resumes.
# Chennai
# 0-1 years
#
# Wilmer Software Solutions Private Limited
# Keyskills: Core Java,  JMS,  Web services
# Summary: Java/J2ee with 5+ years of experience at Chennai location Notice period: 10-15 days
# Chennai, Pune
# 5-10 years
#
# Capgemini Technology Services India Limited
# Keyskills: CoreJava,   Core -  Java... Core Java,  Spring,  strut
#  We would be conducting interviews on below dates 16th June (Saturday)   Intervie..
# Chennai
# 4-10 years
#
# Infiniminds Private Limited
# Keyskills: Spring Mvc,  Spring Boot,   Core Java
# Summary: Company: Infiniminds Client : Wipro location: Chennai Job Description: Bachelor degree (Computer Science) with about 6-10 years of experience in software development - Good experience in Entity mo..
# Chennai
# 6-10 years
#
# Datamatics Global Services Limited
# Keyskills: Java developer,  Core Java J2EE... Core Java, Spring, Hibernat
#  •         Exp. in SQL database:
# Chennai, Mumbai
# 5-8 years
#
# True Tech Solutions
# Keyskills: Core Java Developer
#   immediate to 30 days.
# Chennai
# 3-7 years
#
# Vertical Management Consultancy
# Keyskills: Application Support,   JAVA,   J2EE,   Core...  JAVA,  Advanced  JAVA,  Sprin
# Summary: JAVA / J2EE / Core JAVA / Advanced JAVA Applications Support and Maintenance. Batch Processing, Batch Monitoring, Error Fixing, Bug Fixing, Live Java 24/7 Application Support and Maintenance. etc...
# Chennai
# 2-6 years
#
# Stg Infotech India LLP
# Keyskills: hibernate ,  webservices,   j2ee,   java, ..." Core JAVA",  sprin
# Summary: Java with Spring MVC and Webservices
# Chennai
# 4-9 years
#
# Infiniminds Private Limited
# Keyskills: Spring Mvc,  Spring Boot,   Core Java
# Summary: Company: Infiniminds Client : Wipro location: Chennai Job Description: Bachelor degree (Computer Science) with about 6-10 years of experience in software development - Good experience in Entity mo..
# Chennai
# 6-10 years
#
# Crown Solutions India Private Limited
# Keyskills: Java,   core java
# Summary: Great Opportunity for Java 4+ Yrs of experience Candidates in Chennai Initially you will be onrole of Crown solution if it is Okay please mention Yes/No Candidate Experience: Relavent Experience: ..
# Chennai
# 3-4 years
#
# Larsen & Toubro Infotech  Ltd.
# Keyskills: CoreJava " java", " j2ee", " core...  java", " core java developer", " java
# Chennai
# 3-7 years
#
# savan Sudesh Babu (Proprietor Of Job Store Consulting)
# Keyskills: Mysql,  J2EE, Hibernate,   jdk Core... Java Developer,  Java, UNIX...  java
#  M..
# Chennai
# 5-7 years
#
# Anlage Infotech India Private Limited
# Keyskills: Core Java, SQL Queries
#  You will be a part of a talented software team that works on mission – c..
# Chennai, Mumbai
# 5-8 years
#
# Infiniminds Private Limited
# Keyskills: Spring Mvc,  Spring Boot,   Core Java
# Summary: Company: Infiniminds Client: Wipro Location: Chennai Exp :6-10 Yrs The candidates with the following experience are preferable in building and architecting software solutions in Telecom domain and..
# Chennai
# 6-10 years
#
# VGB IT Solutions
# Keyskills: JAVA,  J2EE,  Core Java, advanced...  java,  EJB,  Hibernate,  JDBC ,  JMS
# Summary: The Applicant will be going to handle various projects based on JAVA,J2EE,Core Java,advanced java, EJB, Hibernate, JDBC , JMS , JSP , OOPS, Ruby, Servlets, Spring , Struts , Websphere
# Chennai, Mumbai
# 0-8 years
#
# 2COMS Consulting Private Limited
# Keyskills: Corejava,   J2EE,   Java...,   core java,  api,  spring boo
# Summary: Position: Java Developer, Sr.developer, lead Exp: 3-9 years Job Location: Chennai interview location: Chennai, bangalore, Hyderabad, Pune JD: Experience in Core Java, Spring MVC, Spring Boot, Spri..
# Chennai
# 3-8 years
#
# Software Data India Limited
# Keyskills: jsp,  servlets,   core java... stack development,   J2ee,   Java
# Summary: Our client is ond ore top renowned IT MNC and scouting for talented resources in Chennai offering work opportunity based at B'lore and Delhi/NCR work location.
# Chennai
# 4-8 years
#
# Crown Solutions India Private Limited
# Keyskills: Java,   j2ee,   core java
# Summary: We have immediate job opportunity for Java developer for Chennai Location. Associates with office notice period more than 30days need not apply. Exp-3+ Interested for F2F ON 9.06.2018 Work Locatio..
# Chennai
# 3-8 years
#
# IQura Technologies Private Limited
# Keyskills: Core Java,  Spring MVC , Spring
# Summary: "We are looking for Core Java Developer"
# Chennai
# 3-9 years
#
# Savvyan Technologies Private Limited
# Keyskills: Core Java,  javascript,  AJAX
#  Exp 5-7 years
# Chennai
# 5-7 years

# %%
l = []
for item in all:
    d = {}
    d["Company"] = item.find_all("div",{"class":"jtxt orange"})[0].text
    d["Title"] = item.find_all("h2",{"class":"seotitle"})[0].text
    try:
        d["Location"] = item.find_all("div",{"class":"jtxt jico ico1"})[0].text
    except:
        d["Location"] = None
    try:
        d["Experience"] = item.find_all("div",{"class":"jtxt jico ico2"})[0].text
    except:
        d["Experience"] = None
    l.append(d)

# %%
l
# Out:
# [{'Company': 'Wipro Limited',
#   'Experience': '5-8 years',
#   'Location': 'Chennai',
#   'Title': 'Tech Lead  Core Java'},
#  {'Company': 'Wipro Limited',
#   'Experience': '3-5 years',
#   'Location': 'Chennai',
#   'Title': 'Developer  Core Java'},
#  {'Company': 'Wipro Limited',
#   'Experience': '3-5 years',
#   'Location': 'Chennai',
#   'Title': 'Developer  Core Java'},
#  {'Company': 'Wipro Limited',
#   'Experience': '3-5 years',
#   'Location': 'Chennai',
#   'Title': 'Developer  Core Java'},
#  {'Company': 'Wipro Limited',
#   'Experience': '3-5 years',
#   'Location': 'Chennai',
#   'Title': 'Developer  Core Java'},
#  {'Company': 'Wipro Limited',
#   'Experience': '3-5 years',
#   'Location': 'Chennai',
#   'Title': 'Developer  Core Java'},
#  {'Company': 'Vertical Management Consultancy',
#   'Experience': '3-6 years',
#   'Location': 'Chennai',
#   'Title': 'Core Java / Advanced  JAVA /  J2EE Developer openings in Chennai'},
#  {'Company': 'Confidential',
#   'Experience': '0-5 years',
#   'Location': 'Chennai, Visakhapatnam',
#   'Title': 'Java Developer & Asp.Net walk in Interview'},
#  {'Company': 'Roljobs Technology Services Private Limited',
#   'Experience': '3-5 years',
#   'Location': 'Chennai',
#   'Title': 'Java Developer'},
#  {'Company': 'Data Software Research Company Private Limited',
#   'Experience': '4-7 years',
#   'Location': 'Chennai',
#   'Title': 'Java Professioanls!!!!'},
#  {'Company': 'Infosys BPM Limited',
#   'Experience': '2-4 years',
#   'Location': 'Chennai',
#   'Title': 'Java Developer'},
#  {'Company': '2COMS Consulting Private Limited',
#   'Experience': '3-8 years',
#   'Location': 'Chennai',
#   'Title': 'Core Java Developer with Multithreading, collections, OOPS for Chennai'},
#  {'Company': 'Wipro Limited',
#   'Experience': '5-8 years',
#   'Location': 'Chennai',
#   'Title': 'Tech Lead  Core Java'},
#  {'Company': 'HR Addons',
#   'Experience': '4-7 years',
#   'Location': 'Chennai',
#   'Title': 'Java Developer'},
#  {'Company': 'Cloud Axis Technologies',
#   'Experience': '0-0 years',
#   'Location': 'Chennai',
#   'Title': 'Java Developer'},
#  {'Company': 'SP Staffing Services Private Limited',
#   'Experience': '3-6 years',
#   'Location': 'Chennai',
#   'Title': 'We are having an opening for  Java Developer and DotNet Developer in MNC company.'},
#  {'Company': 'Perficient India',
#   'Experience': '4-12 years',
#   'Location': 'Chennai',
#   'Title': 'Senior  Java Developer'},
#  {'Company': 'People Prime Worldwide Private Limited',
#   'Experience': '5-10 years',
#   'Location': 'Mumbai, Chennai',
#   'Title': 'Immediate Opening at BA Continuum'},
#  {'Company': 'Comfyi Solution',
#   'Experience': '0-1 years',
#   'Location': 'Chennai',
#   'Title': 'Core Java Developer'},
#  {'Company': 'Wilmer Software Solutions Private Limited',
#   'Experience': '5-10 years',
#   'Location': 'Chennai, Pune',
#   'Title': 'Java /  J2ee with 5+ years of experience at Chennai location Notice period: 10-15 days'},
#  {'Company': 'Capgemini Technology Services India Limited',
#   'Experience': '4-10 years',
#   'Location': 'Chennai',
#   'Title': 'Walk-in Interview -  Java Developer - Capgemini Chennai on 16th June 2018'},
#  {'Company': 'Infiniminds Private Limited',
#   'Experience': None,
#   'Location': None,
#   'Title': 'J2Ee Developer'},
#  {'Company': 'Datamatics Global Services Limited',
#   'Experience': '5-8 years',
#   'Location': 'Chennai, Mumbai',
#   'Title': 'Excellent opportunity with Datamatics for Senior  Java Developer position'},
#  {'Company': 'True Tech Solutions',
#   'Experience': '3-7 years',
#   'Location': 'Chennai',
#   'Title': 'Core Java Developer :: Guindy location'},
#  {'Company': 'Vertical Management Consultancy',
#   'Experience': '2-6 years',
#   'Location': 'Chennai',
#   'Title': 'JAVA /  J2EE /  Core JAVA / Advanced  JAVA Production and Application Support'},
#  {'Company': 'Stg Infotech India LLP',
#   'Experience': '4-9 years',
#   'Location': 'Chennai',
#   'Title': 'Openings with STG For  Java with Spring Professionals'},
#  {'Company': 'Infiniminds Private Limited',
#   'Experience': None,
#   'Location': None,
#   'Title': 'J2Ee Developer'},
#  {'Company': 'Crown Solutions India Private Limited',
#   'Experience': '3-4 years',
#   'Location': 'Chennai',
#   'Title': 'Java Developer'},
#  {'Company': 'Larsen & Toubro Infotech  Ltd.',
#   'Experience': '3-7 years',
#   'Location': 'Chennai',
#   'Title': 'Opening for  Java developer@Chennai'},
#  {'Company': 'savan Sudesh Babu (Proprietor Of Job Store Consulting)',
#   'Experience': None,
#   'Location': None,
#   'Title': 'SENIOR  JAVA DEVELOPER'},
#  {'Company': 'Anlage Infotech India Private Limited',
#   'Experience': '5-8 years',
#   'Location': 'Chennai, Mumbai',
#   'Title': 'Senior  Java Developer'},
#  {'Company': 'Infiniminds Private Limited',
#   'Experience': None,
#   'Location': None,
#   'Title': 'J2EE Lead'},
#  {'Company': 'VGB IT Solutions',
#   'Experience': '0-8 years',
#   'Location': 'Chennai, Mumbai',
#   'Title': 'Java /  J2ee- Developers / team lead / Architect'},
#  {'Company': '2COMS Consulting Private Limited',
#   'Experience': '3-8 years',
#   'Location': 'Chennai',
#   'Title': 'Java Development Professionals'},
#  {'Company': 'Software Data India Limited',
#   'Experience': '4-8 years',
#   'Location': 'Chennai',
#   'Title': 'Java Developer (front end Development)'},
#  {'Company': 'Crown Solutions India Private Limited',
#   'Experience': '3-8 years',
#   'Location': 'Chennai',
#   'Title': 'Excillent Opportunity for  Java Developer C2H Position F2F on 9th'},
#  {'Company': 'IQura Technologies Private Limited',
#   'Experience': '3-9 years',
#   'Location': 'Chennai',
#   'Title': '" Core Java Developer"'},
#  {'Company': 'Savvyan Technologies Private Limited',
#   'Experience': '5-7 years',
#   'Location': 'Chennai',
#   'Title': 'Java Developer'}]

# %%
len(l)
# Out:
# 38

# %%
import pandas
df = pandas.DataFrame(l)

# %%
df
# Out:
#                                               Company  Experience  \
# 0                                       Wipro Limited   5-8 years
# 1                                       Wipro Limited   3-5 years
# 2                                       Wipro Limited   3-5 years
# 3                                       Wipro Limited   3-5 years
# 4                                       Wipro Limited   3-5 years
# 5                                       Wipro Limited   3-5 years
# 6                     Vertical Management Consultancy   3-6 years
# 7                                        Confidential   0-5 years
# 8         Roljobs Technology Services Private Limited   3-5 years
# 9      Data Software Research Company Private Limited   4-7 years
# 10                                Infosys BPM Limited   2-4 years
# 11                   2COMS Consulting Private Limited   3-8 years
# 12                                      Wipro Limited   5-8 years
# 13                                          HR Addons   4-7 years
# 14                            Cloud Axis Technologies   0-0 years
# 15               SP Staffing Services Private Limited   3-6 years
# 16                                   Perficient India  4-12 years
# 17             People Prime Worldwide Private Limited  5-10 years
# 18                                    Comfyi Solution   0-1 years
# 19          Wilmer Software Solutions Private Limited  5-10 years
# 20        Capgemini Technology Services India Limited  4-10 years
# 21                        Infiniminds Private Limited        None
# 22                 Datamatics Global Services Limited   5-8 years
# 23                                True Tech Solutions   3-7 years
# 24                    Vertical Management Consultancy   2-6 years
# 25                             Stg Infotech India LLP   4-9 years
# 26                        Infiniminds Private Limited        None
# 27              Crown Solutions India Private Limited   3-4 years
# 28                     Larsen & Toubro Infotech  Ltd.   3-7 years
# 29  savan Sudesh Babu (Proprietor Of Job Store Con...        None
# 30              Anlage Infotech India Private Limited   5-8 years
# 31                        Infiniminds Private Limited        None
# 32                                   VGB IT Solutions   0-8 years
# 33                   2COMS Consulting Private Limited   3-8 years
# 34                        Software Data India Limited   4-8 years
# 35              Crown Solutions India Private Limited   3-8 years
# 36                 IQura Technologies Private Limited   3-9 years
# 37               Savvyan Technologies Private Limited   5-7 years
#
#                   Location                                              Title
# 0                  Chennai                               Tech Lead  Core Java
# 1                  Chennai                               Developer  Core Java
# 2                  Chennai                               Developer  Core Java
# 3                  Chennai                               Developer  Core Java
# 4                  Chennai                               Developer  Core Java
# 5                  Chennai                               Developer  Core Java
# 6                  Chennai  Core Java / Advanced  JAVA /  J2EE Developer o...
# 7   Chennai, Visakhapatnam         Java Developer & Asp.Net walk in Interview
# 8                  Chennai                                     Java Developer
# 9                  Chennai                             Java Professioanls!!!!
# 10                 Chennai                                     Java Developer
# 11                 Chennai  Core Java Developer with Multithreading, colle...
# 12                 Chennai                               Tech Lead  Core Java
# 13                 Chennai                                     Java Developer
# 14                 Chennai                                     Java Developer
# 15                 Chennai  We are having an opening for  Java Developer a...
# 16                 Chennai                             Senior  Java Developer
# 17         Mumbai, Chennai                  Immediate Opening at BA Continuum
# 18                 Chennai                                Core Java Developer
# 19           Chennai, Pune  Java /  J2ee with 5+ years of experience at Ch...
# 20                 Chennai  Walk-in Interview -  Java Developer - Capgemin...
# 21                    None                                     J2Ee Developer
# 22         Chennai, Mumbai  Excellent opportunity with Datamatics for Seni...
# 23                 Chennai             Core Java Developer :: Guindy location
# 24                 Chennai  JAVA /  J2EE /  Core JAVA / Advanced  JAVA Pro...
# 25                 Chennai  Openings with STG For  Java with Spring Profes...
# 26                    None                                     J2Ee Developer
# 27                 Chennai                                     Java Developer
# 28                 Chennai                Opening for  Java developer@Chennai
# 29                    None                             SENIOR  JAVA DEVELOPER
# 30         Chennai, Mumbai                             Senior  Java Developer
# 31                    None                                          J2EE Lead
# 32         Chennai, Mumbai   Java /  J2ee- Developers / team lead / Architect
# 33                 Chennai                     Java Development Professionals
# 34                 Chennai             Java Developer (front end Development)
# 35                 Chennai  Excillent Opportunity for  Java Developer C2H ...
# 36                 Chennai                             " Core Java Developer"
# 37                 Chennai                                     Java Developer

# %%
df.to_csv("Monster_1.csv")
